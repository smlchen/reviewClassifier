# %%
# Import packages.
import numpy as np
import pandas as pd
import nltk
import nltk.corpus
import gzip
import json
import re
from nltk.corpus import wordnet

# %% [markdown]
# #### Build function to clean text with test data.

# %%
def parse(path):
  g = gzip.open(path, 'r')
  for l in g:
    yield json.loads(l)
    
    
def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF("../../../Downloads/AMAZON_FASHION_5.json.gz")

# %%
df.head()
# Out:
#    overall  verified  reviewTime     reviewerID        asin  \
# 0      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 1      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 2      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 3      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 4      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
#
#                                                style reviewerName  \
# 0   {'Size:': ' Big Boys', 'Color:': ' Blue/Orange'}     Tonya B.
# 1  {'Size:': ' Big Boys', 'Color:': ' Black (3746...     Tonya B.
# 2  {'Size:': ' Big Boys', 'Color:': ' Blue/Gray L...     Tonya B.
# 3  {'Size:': ' Big Boys', 'Color:': ' Blue (37867...     Tonya B.
# 4     {'Size:': ' Big Boys', 'Color:': ' Blue/Pink'}     Tonya B.
#
#                  reviewText     summary  unixReviewTime vote image
# 0  Great product and price!  Five Stars      1441324800  NaN   NaN
# 1  Great product and price!  Five Stars      1441324800  NaN   NaN
# 2  Great product and price!  Five Stars      1441324800  NaN   NaN
# 3  Great product and price!  Five Stars      1441324800  NaN   NaN
# 4  Great product and price!  Five Stars      1441324800  NaN   NaN

# %%
np.shape(df)
# Out:
# (3176, 12)

# %%
# Drop duplicate reviews
df_nodup = df.drop_duplicates(subset = ['reviewText'])

# %%
def tokenize_text(doc):
    """
    Input: A string of words.
    Output: List of tokenized words that are all lowercase.
    """

    # Tokenize and make lowercase.
    words = nltk.word_tokenize(doc)
    words = [w.lower() for w in words]
    
    return words


def wordnet_pos(tag):
    """
    Map a Brown POS tag to a WordNet POS tag. This is for lemmatization.
    """
    
    table = {"N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV, "J": wordnet.ADJ}
    
    # Default to a noun.
    return table.get(tag[0], wordnet.NOUN)


def lemmatize_text(words):
    """
    Input: A list of tokenized words.
    Output: A list of tokenized words that are lemmatized.
    """
    
    lemmatizer = nltk.WordNetLemmatizer()
    word_tags = nltk.pos_tag(words)
    words = [lemmatizer.lemmatize(w, wordnet_pos(t)) for (w, t) in word_tags]
    
    return words


def remove_stopwords(words):
    """
    Input: A list of tokenized words.
    Output: A list of tokenized words that have stopwords removed.
    """
    
    stopwords = nltk.corpus.stopwords.words("english")
    words = [w for w in words if w not in stopwords]
    
    return words

def clean_text(doc): 
    """
    Input: A string of words.
    Output: A string of words that has been lemmatized, has the stopwords removed, and has the puncuation removed.
    """
    
    words = re.sub("< ?/?[a-z]+ ?>|\n", "", doc)
    words = tokenize_text(words)
    words = lemmatize_text(words)
    words = remove_stopwords(words)
    doc = [w for w in words if w.isalnum()]
    doc = ' '.join(doc)
    
    return doc

def clean_df(df):
    """
    Input: A dataframe with a column of reviews called 'reviewText'.
    Output: The same dataframe as the input, but with an extra column called 'text' which has the 
            cleaned 'reviewText'.
    """
    
    text = df['reviewText']
    df_clean = df.copy()
    df_clean['text'] = [clean_text(str(i)) for i in text]

    return df_clean

# %%
print(df['reviewText'][10])
print(clean_text(df['reviewText'][10]))
# Out:
# Relieved my Plantar Fascitis for 3 Days. Then the unbearable pain returned in full force. These were recommended by my Podiatrist.
# relieve plantar fascitis 3 day unbearable pain return full force recommend podiatrist

# %%
print(df['reviewText'][300])
print(clean_text(df['reviewText'][300]))
# Out:
# Love these sneakers. Light weight and comfortable even without socks.
# love sneaker light weight comfortable even without sock

# %%
# Test the function
clean_df(df_nodup)[['reviewText', 'text']].head()
# Out:
#                                           reviewText  \
# 0                           Great product and price!
# 5      Waaay too small. Will use for futur children!
# 6                    Stays vibrant after many washes
# 8  My son really likes the pink. Ones which I was...
# 9        Waaay too small. Will use for future child.
#
#                                text
# 0               great product price
# 5       waaay small use futur child
# 6            stay vibrant many wash
# 8  son really like pink one nervous
# 9      waaay small use future child

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range=(1,3), norm='l2')

# tmp = df['text']

# vectorizer.fit(tmp)

# tmp_tfidf = vectorizer.transform(tmp)

# %% [markdown]
# #### Clean the amazon data.

# %%
# Clean the amazon text.
amazon = pd.read_csv('~/Downloads/GroupProject/AMAZON.csv')

# %%
amazon.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        1      True  05 11, 2016  A2E4NSDWJDXHYL  B00ZWWMHTI
# 1        2      True  08 23, 2016  A1RZ7GEW807WFX  B01B298Q0S
# 2        5      True  06 29, 2014  A1NWDBD77LQ3MB  B00104KJ4C
# 3        5      True  02 15, 2014  A1487V05K2FBK4  B000X9FV5M
# 4        5      True   03 4, 2014  A2N8ZEA5I6TOPA  B00GV4V8XC
#
#                                                style  reviewerName  \
# 0                                                NaN         M. O.
# 1                         {'Platform:': ' Xbox One'}  Valerie Reed
# 2                         {'Format:': ' Video Game'}             X
# 3                         {'Format:': ' Video Game'}  Roger Huston
# 4  {'Edition:': ' Standard', 'Platform:': ' Ninte...     Daniel G.
#
#                                           reviewText  \
# 0  Did not fit properly no matter what I did. Eve...
# 1                                 Meh. Underwhelming
# 2  I love it and world recommend this game to my ...
# 3  Far Cry 2 is a very enjoyable FPS.  The immens...
# 4  There is much to like about the game, even if ...
#
#                              summary  unixReviewTime vote  \timage  \
# 0                        Not for me.      1462924800  NaN      NaN
# 1                          Two Stars      1471910400  NaN      NaN
# 2  Arrived Fast & Got What I Order~!      1404000000  NaN      NaN
# 3                 Fun, fun, fun game      1392422400  NaN      NaN
# 4                       Awesome game      1393891200  NaN      NaN
#
#              Category
# 0  Video_Games_5.json
# 1  Video_Games_5.json
# 2  Video_Games_5.json
# 3  Video_Games_5.json
# 4  Video_Games_5.json

# %%
clean_data = clean_df(amazon)

# %%
clean_data.to_csv(r'~/Documents/ECS171/reviewClassifier/clean_data.csv')

# %%
clean_data
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 0            1      True  05 11, 2016  A2E4NSDWJDXHYL  B00ZWWMHTI
# 1            2      True  08 23, 2016  A1RZ7GEW807WFX  B01B298Q0S
# 2            5      True  06 29, 2014  A1NWDBD77LQ3MB  B00104KJ4C
# 3            5      True  02 15, 2014  A1487V05K2FBK4  B000X9FV5M
# 4            5      True   03 4, 2014  A2N8ZEA5I6TOPA  B00GV4V8XC
# 5            5      True  01 13, 2017  A1Z3NP8LJB8PQO  B003YMMGEE
# 6            5      True  07 14, 2014  A1Z7TAQGXOC4QL  B00109KMOO
# 7            5      True  03 23, 2015  A2RODTBQJX7QM7  B00BAWXCP2
# 8            4     False  08 24, 2006  A1K31NF81TS0CO  B0002KMHD6
# 9            5     False   07 4, 2002  A3ER878Z9WVNRO  B0000631WO
# 10           5      True  12 18, 2017  A2BO3O5UVQ8UG3  B00A878J4E
# 11           5      True  06 21, 2014  A2BJURUTPLM7ZW  B001EQPDO2
# 12           5      True  09 22, 2015   AZTJX0Y6JJKL9  B000VTQ3LU
# 13           4      True  02 23, 2013  A3LTK1JJA7G052  B007LQG9A6
# 14           2     False  05 14, 2008  A2PT1M0S0S3AOP  B0001Y7404
# 15           5      True  06 29, 2017  A2A3BQDXV82PZX  B006JKASCK
# 16           5      True  04 17, 2017   ACG14SVOMCMG1  B01EJ9DMQQ
# 17           5      True  09 23, 2015   AUHNOD6W2GI1Q  B002BSC5CU
# 18           5      True  08 19, 2014  A2B1OM6AN53PKQ  B006ZTHFPS
# 19           1     False  07 10, 2007  A1B124AVX0QH2B  B000B43OY4
# 20           4      True  05 10, 2013   AXVZA3CQYLQB5  B000SBR9JQ
# 21           5     False  04 13, 2016   AW7QUVVFVABUU  B00C7103JI
# 22           3      True  09 27, 2008  A1D2QG6A2RI8VN  B00127VE2S
# 23           5      True  04 14, 2013  A2OSJWDJWPH3VU  B00ARCWQPS
# 24           4      True   12 4, 2015   AWXWYHD0T3O9B  B002I096Q4
# 25           5      True  08 15, 2015  A2RZU6WMU5ZS2U  B0012N94WO
# 26           5      True  09 12, 2014  A21B8AV7E3MPXE  B0050SW2NA
# 27           5      True  01 18, 2016   A3UC5F1WUR1X8  B00L59D9HG
# 28           5      True  08 19, 2015  A1F41PH89SL6JB  B00EC6W1O6
# 29           4      True   05 9, 2016  A2UKONYF8II9SY  B000P297F2
# ...        ...       ...          ...             ...         ...
# 14470        1      True  04 30, 2012  A2Y7BUPYLEZ6PE  0007230206
# 14471        2      True   08 6, 2009  A2C0ALI7MLHLJZ  0007203136
# 14472        2      True   02 1, 2017  A35G8XLKENLP7J  0007155662
# 14473        5      True  09 14, 2007  A3KEZLJ59C1JVH  0006551807
# 14474        5      True  02 21, 2013   ABPEBP0UWFUK2  0006064922
# 14475        5      True   12 1, 2013  A2REG1E0F7XXJL  0004704746
# 14476        1      True  08 18, 2016   AMB4EDY6W3AKG  0002256649
# 14477        2     False  05 26, 2015  A1XE2JOZZKMEG6  0006172768
# 14478        5     False  12 16, 2005  A2YM3KILJ1G0YJ  0001720295
# 14479        5     False   03 6, 2015  A2MIOICG0DSFP1  0002247437
# 14480        5     False   04 6, 2003  A1TV8O1XY9HREW  0001844423
# 14481        5      True  04 10, 2015  A3LPE4KR3HOU6E  0001048767
# 14482        5      True  04 12, 2018  A25ET3S2F77G0K  0006280544
# 14483        4     False  10 28, 2015  A35R2NR30DMZXV  0007271239
# 14484        5      True  01 22, 2016  A1TYREQ3RW7QKP  0001048767
# 14485        5      True  07 23, 2001  A24AGAOVQ9V1AT  0007155662
# 14486        3      True  07 19, 2014  A13B1RL2P1CKMP  0007215053
# 14487        5      True   01 2, 2015  A2BA1V80XPVO4P  0006064922
# 14488        5      True  07 15, 2013  A329BKRM2USZ8T  000100039X
# 14489        5      True  09 16, 2017  A253E4EDXHUPF9  0006367992
# 14490        5      True  07 26, 2011  A1NY3WJ1L8CD94  0002247437
# 14491        3      True  04 24, 2010  A3TMZZM7NX8SR9  0007242476
# 14492        5      True  01 13, 2017  A3J5OJ1NLYWD00  0001945424
# 14493        5     False  02 21, 2010  A2ANWGPM3M2JPD  0001844423
# 14494        5      True  04 25, 2013  A1Q4H73Z61HA90  000711835X
# 14495        5      True  09 14, 2009  A3LKQQ63SU32ZY  0007173148
# 14496        5     False  08 21, 2004   A4FX5YCJA630V  000711835X
# 14497        5      True  04 11, 2016  A3L086I9O5BF0A  0007271239
# 14498        5      True  02 11, 2018  A3MM0D7ORPE2OV  0001048767
# 14499        5      True  07 27, 2017   A5FZ56CUI06UN  0006476414
#
#                                                    style  \
# 0                                                    NaN
# 1                             {'Platform:': ' Xbox One'}
# 2                             {'Format:': ' Video Game'}
# 3                             {'Format:': ' Video Game'}
# 4      {'Edition:': ' Standard', 'Platform:': ' Ninte...
# 5                                   {'Platform:': ' PC'}
# 6                             {'Platform:': ' Xbox 360'}
# 7                        {'Style:': ' Standard Edition'}
# 8                                                    NaN
# 9                                                    NaN
# 10                                  {'Color:': ' Black'}
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                        {'Platform:': ' PlayStation2'}
# 15                                {'Edition:': ' 32 GB'}
# 16                                                   NaN
# 17                                                   NaN
# 18                            {'Format:': ' Video Game'}
# 19                     {'Edition:': ' Pro Console 20GB'}
# 20                                                   NaN
# 21                            {'Format:': ' Video Game'}
# 22                                                   NaN
# 23                                                   NaN
# 24                            {'Format:': ' Video Game'}
# 25                            {'Format:': ' Video Game'}
# 26                                                   NaN
# 27                                                   NaN
# 28                             {'Edition:': ' Rapunzel'}
# 29                            {'Format:': ' Video Game'}
# ...                                                  ...
# 14470                          {'Format:': ' Paperback'}
# 14471                          {'Format:': ' Paperback'}
# 14472                          {'Format:': ' Paperback'}
# 14473                          {'Format:': ' Paperback'}
# 14474                     {'Format:': ' Kindle Edition'}
# 14475                          {'Format:': ' Hardcover'}
# 14476                                                NaN
# 14477              {'Format:': ' Mass Market Paperback'}
# 14478                          {'Format:': ' Hardcover'}
# 14479                                                NaN
# 14480                          {'Format:': ' Hardcover'}
# 14481              {'Format:': ' Mass Market Paperback'}
# 14482                          {'Format:': ' Paperback'}
# 14483                          {'Format:': ' Paperback'}
# 14484                                                NaN
# 14485                          {'Format:': ' Paperback'}
# 14486                     {'Format:': ' Kindle Edition'}
# 14487                     {'Format:': ' Kindle Edition'}
# 14488                                                NaN
# 14489                     {'Format:': ' Kindle Edition'}
# 14490                                                NaN
# 14491                     {'Format:': ' Kindle Edition'}
# 14492              {'Format:': ' Mass Market Paperback'}
# 14493                          {'Format:': ' Paperback'}
# 14494    {'Format:': ' Kindle Edition with Audio/Video'}
# 14495                          {'Format:': ' Hardcover'}
# 14496                           {'Format:': ' Audio CD'}
# 14497                     {'Format:': ' Kindle Edition'}
# 14498                          {'Format:': ' Paperback'}
# 14499                     {'Format:': ' Kindle Edition'}
#
#                     reviewerName  \
# 0                          M. O.
# 1                   Valerie Reed
# 2                              X
# 3                   Roger Huston
# 4                      Daniel G.
# 5                        Jarhead
# 6                    Khalil Rahi
# 7                      Luis Soto
# 8                       Dubyac99
# 9                    Kopaka Nuva
# 10                    Ryan Hardy
# 11                          Mary
# 12                          Evan
# 13                      R. Davis
# 14               Johnathan Doler
# 15                 Robert Lawson
# 16                         Grant
# 17                      Fritters
# 18                    Seth Davis
# 19                      SiskoDS9
# 20                 Keenan Hansen
# 21                          John
# 22               Francisco Rojas
# 23                       Avelier
# 24                Curtis Woodard
# 25                 Yasmily Lopez
# 26            Natalie V. Galasso
# 27             The shopping lady
# 28                         Paige
# 29                Sulimar Rivera
# ...                          ...
# 14470                      vmcla
# 14471        Anthony W. Waggoner
# 14472                         Az
# 14473            Amazon Customer
# 14474               Carolyn Bean
# 14475                    Grace11
# 14476                 Jim Rinker
# 14477                 Wikileaker
# 14478                      Jason
# 14479          Larry Fitzpatrick
# 14480                FlyingDream
# 14481                      aubie
# 14482                      joyce
# 14483             Sam&#039;s mom
# 14484                     Vildan
# 14485               TexyInAustin
# 14486                    Johanna
# 14487  darrell lewis willis, sr.
# 14488                        Jay
# 14489                  L. Brooks
# 14490              csaszarzoltan
# 14491         Denise S. Trussell
# 14492                        Jan
# 14493       Sandra Iler Kirkland
# 14494               Pat Rossiter
# 14495               Englishwades
# 14496               R. M. Fisher
# 14497                Nikki Hanna
# 14498                     Nicola
# 14499                E. Mehlhorn
#
#                                               reviewText  \
# 0      Did not fit properly no matter what I did. Eve...
# 1                                     Meh. Underwhelming
# 2      I love it and world recommend this game to my ...
# 3      Far Cry 2 is a very enjoyable FPS.  The immens...
# 4      There is much to like about the game, even if ...
# 5                                        Bought as gift?
# 6       Great service, arrived sooner then excepted. A++
# 7      Great game. Lengthy and enjoyable. New game+ a...
# 8      I have to say, first of all, I made a killing ...
# 9      This is a very good game to play, but it didn'...
# 10                                                 Great
# 11     thiis is a great game to play the whole family...
# 12     Great refurbed PS3 eye.  Just what I needed an...
# 13     This is great, Its NOT an xbox 360 controller ...
# 14     When you get a series like Silent Hill, your e...
# 15        Thank you,wish the card was cheaper price wise
# 16     I had one of the small blue clips that holds t...
# 17     Great game. I loved it and played it for month...
# 18     Awesome game! I played Mortal Kombat as a kid....
# 19     MicroSoft is Being Sued for the X360 Scratchin...
# 20     this one has some pretty hard levels to be abl...
# 21     I for one actually liked this game. It gets a ...
# 22     The original one that come with the Wii is far...
# 23     I will split my review into 2 parts because mo...
# 24     Really addicting game... I'm a constant FPS an...
# 25                                                 bueno
# 26     I adore the little big planet game.  I had thi...
# 27     So far so good had it since 25th of December a...
# 28     Who doesn't love Rapunzel?  She was a great ad...
# 29                                       Its a good game
# ...                                                  ...
# 14470  Well in Wolf Hall we have another book which f...
# 14471  The first two novels had built me up for an as...
# 14472  I saw this author interviewed on TV, so I thou...
# 14473  "The Namesake" is the story of Gogol Ganguli, ...
# 14474  The KJV of the Bible in my mind is the only or...
# 14475  An excellent edition to keep on hand in the cl...
# 14476  In my opinion,  this book was at least twice a...
# 14477  Clancy's first and most popular novel, later r...
# 14478  Four children are sent to live away from home ...
# 14479  Well I have finished four of the books. I need...
# 14480  One of the most beloved stories of all times. ...
# 14481                             had to read for school
# 14482  Haven't read it yet but I keep hearing quotes ...
# 14483  I loved this book! I didn't like what he wrote...
# 14484                                          Thank you
# 14485  This is one of the most amazing books I have e...
# 14486  I went back to reading this book just as I was...
# 14487                         getting good use out of it
# 14488  Truly a classic of world literature, Gibran ha...
# 14489  Great book with lots of juicy tidbits about Mr...
# 14490  I don't share other people's opinion that the ...
# 14491  That's how this reads. Large amount of chapter...
# 14492                               Beautifully Written.
# 14493  In this, the fifth book of The Chronicles Of N...
# 14494  A beautiful book, illustrated by the author in...
# 14495  I recommend this book for anyone who reads to ...
# 14496  Even today, almost six decades since its first...
# 14497  I loved this book. My son recommended it to me...
# 14498                                            Like it
# 14499  I have read many of Clancy's Jack Ryan books s...
#
#                                                  summary  unixReviewTime vote  \
# 0                                            Not for me.      1462924800  NaN
# 1                                              Two Stars      1471910400  NaN
# 2                      Arrived Fast & Got What I Order~!      1404000000  NaN
# 3                                     Fun, fun, fun game      1392422400  NaN
# 4                                           Awesome game      1393891200  NaN
# 5                                            Great Game.      1484265600  NaN
# 6                                             Five Stars      1405296000  NaN
# 7                      Great game. Lengthy and enjoyable      1427068800  NaN
# 8                   Fun, but hard to control at times...      1156377600    4
# 9                          A very good dragonball z game      1025740800    5
# 10                                            Five Stars      1513555200  NaN
# 11                                                 great      1403308800  NaN
# 12                              Great Cam for the money.      1442880000  NaN
# 13                                             It works!      1361577600  NaN
# 14               ABC: Apathetic, Boring and Cantankerous      1210723200  NaN
# 15                                            Five Stars      1498694400  NaN
# 16                                Great customer service      1492387200    7
# 17                               Fun and worth the price      1442966400  NaN
# 18                                            Five Stars      1408406400  NaN
# 19                    Breaks Often, Scratches Game Disks      1184025600    4
# 20                    love the first one, like this one.      1368144000  NaN
# 21                                  A good game I think.      1460505600  NaN
# 22                            The Original one is better      1222473600  NaN
# 23                                    A Very Unique Game      1365897600  NaN
# 24     I love the random generated stats\drops and gr...      1449187200  NaN
# 25                                            Five Stars      1439596800  NaN
# 26                                        LOVE THIS GAME      1410480000  NaN
# 27                                            Five Stars      1453075200  NaN
# 28                                  Rapunzel for the win      1439942400  NaN
# 29                                                  Nice      1462752000  NaN
# ...                                                  ...             ...  ...
# 14470     Conventional Wisdom STINKS; so does this book.      1335744000   14
# 14471                                      Disappointing      1249516800    4
# 14472                                          Overrated      1485907200  NaN
# 14473                        Caught between two cultures      1189728000   25
# 14474                                    God's Holy Word      1361404800  NaN
# 14475                                             Great!      1385856000  NaN
# 14476                            Did not enjoy it at all      1471478400  NaN
# 14477             preposterous premise, sorrily executed      1432598400  NaN
# 14478                   An absolutely  wonderful fantasy      1134691200    4
# 14479                               Four down one to go?      1425600000  NaN
# 14480                                   A Roar Of a Lion      1049587200  NaN
# 14481                                             boring      1428624000  NaN
# 14482                                         Five Stars      1523491200  NaN
# 14483  If you love dogs and/or racing this is a must ...      1445990400  NaN
# 14484                                         Five Stars      1453420800  NaN
# 14485                                            Awesome       995846400    3
# 14486         Interesting, yet ultimately disappointing.      1405728000    3
# 14487                                         Five Stars      1420156800  NaN
# 14488                                         A treasure      1373846400  NaN
# 14489                     Can't Get Enough of Cary Grant      1505520000  NaN
# 14490  The most underrated and misunderstood book in ...      1311638400  NaN
# 14491                                 Make me a TV drama      1272067200  NaN
# 14492                                   The Secret's Out      1484265600  NaN
# 14493            Highly Recommended Family Entertainment      1266710400  NaN
# 14494                    A must have for any Tolkien fan      1366848000  NaN
# 14495                                Dr. Seuss is great!      1252886400  NaN
# 14496    "Drums, Drums in the Deep...They are Coming..."      1093046400    2
# 14497                                  I loved this book      1460332800  NaN
# 14498                                         Five Stars      1518307200  NaN
# 14499  I have read many of Clancy's Jack Ryan books s...      1501113600  NaN
#
#        \timage            Category  \
# 0          NaN  Video_Games_5.json
# 1          NaN  Video_Games_5.json
# 2          NaN  Video_Games_5.json
# 3          NaN  Video_Games_5.json
# 4          NaN  Video_Games_5.json
# 5          NaN  Video_Games_5.json
# 6          NaN  Video_Games_5.json
# 7          NaN  Video_Games_5.json
# 8          NaN  Video_Games_5.json
# 9          NaN  Video_Games_5.json
# 10         NaN  Video_Games_5.json
# 11         NaN  Video_Games_5.json
# 12         NaN  Video_Games_5.json
# 13         NaN  Video_Games_5.json
# 14         NaN  Video_Games_5.json
# 15         NaN  Video_Games_5.json
# 16         NaN  Video_Games_5.json
# 17         NaN  Video_Games_5.json
# 18         NaN  Video_Games_5.json
# 19         NaN  Video_Games_5.json
# 20         NaN  Video_Games_5.json
# 21         NaN  Video_Games_5.json
# 22         NaN  Video_Games_5.json
# 23         NaN  Video_Games_5.json
# 24         NaN  Video_Games_5.json
# 25         NaN  Video_Games_5.json
# 26         NaN  Video_Games_5.json
# 27         NaN  Video_Games_5.json
# 28         NaN  Video_Games_5.json
# 29         NaN  Video_Games_5.json
# ...        ...                 ...
# 14470      NaN        Books_5.json
# 14471      NaN        Books_5.json
# 14472      NaN        Books_5.json
# 14473      NaN        Books_5.json
# 14474      NaN        Books_5.json
# 14475      NaN        Books_5.json
# 14476      NaN        Books_5.json
# 14477      NaN        Books_5.json
# 14478      NaN        Books_5.json
# 14479      NaN        Books_5.json
# 14480      NaN        Books_5.json
# 14481      NaN        Books_5.json
# 14482      NaN        Books_5.json
# 14483      NaN        Books_5.json
# 14484      NaN        Books_5.json
# 14485      NaN        Books_5.json
# 14486      NaN        Books_5.json
# 14487      NaN        Books_5.json
# 14488      NaN        Books_5.json
# 14489      NaN        Books_5.json
# 14490      NaN        Books_5.json
# 14491      NaN        Books_5.json
# 14492      NaN        Books_5.json
# 14493      NaN        Books_5.json
# 14494      NaN        Books_5.json
# 14495      NaN        Books_5.json
# 14496      NaN        Books_5.json
# 14497      NaN        Books_5.json
# 14498      NaN        Books_5.json
# 14499      NaN        Books_5.json
#
#                                                     text
# 0      fit properly matter even could get work right ...
# 1                                      meh underwhelming
# 2      love world recommend game friend complaint als...
# 3      far cry 2 enjoyable fps immense open gameplay ...
# 4      much like game even fault scatter throughout e...
# 5                                               buy gift
# 6                     great service arrive sooner except
# 7      great game lengthy enjoyable new vita get game...
# 8      say first make killing game buy go business sa...
# 9      good game play follow storyline good first lea...
# 10                                                 great
# 11     thiis great game play whole family play day be...
# 12           great refurbed ps3 eye need price wonderful
# 13     great xbox 360 controller work like one use xb...
# 14     get series like silent hill expectation go pre...
# 15                      thank wish card cheap price wise
# 16     one small blue clip hold game rack break first...
# 17       great game love play month end buy sequel thing
# 18     awesome game play mortal kombat kid awesome wo...
# 19     microsoft sue x360 scratching game disk one ev...
# 20     one pretty hard level able see really able con...
# 21     one actually like game get bad wrap ca see get...
# 22     original one come wii far well expend little b...
# 23     split review 2 part people focus game also tal...
# 24     really addicting game constant fps rpg player ...
# 25                                                 bueno
# 26     adore little big planet game game playstation ...
# 27     far good since 25th december work pretty good ...
# 28     love rapunzel great addition toy box disney in...
# 29                                             good game
# ...                                                  ...
# 14470  well wolf hall another book float success buil...
# 14471  first two novel build astonishimg climax even ...
# 14472  saw author interview tv thought buy famous boo...
# 14473  namesake story gogol ganguli man bear indian p...
# 14474  kjv bible mind original version bible would re...
# 14475  excellent edition keep hand classroom student ...
# 14476  opinion book least twice long need convey stor...
# 14477  clancy first popular novel later republish fea...
# 14478  four child send live away home war stumble upo...
# 14479  well finish four book need short break book fi...
# 14480  one beloved story time sort hard forget talk l...
# 14481                                        read school
# 14482          read yet keep hear quote almost time read
# 14483  love book like write regard minor try seduce t...
# 14484                                              thank
# 14485  one amazing book ever read feel tongue tie try...
# 14486  go back read book petersburg vacation trip vis...
# 14487                                       get good use
# 14488  truly classic world literature gibran snatch c...
# 14489  great book lot juicy tidbit beautiful cary gra...
# 14490  share people opinion feast crow failure think ...
# 14491  read large amount chapter minimal character st...
# 14492                                  beautifully write
# 14493  fifth book chronicle narnia lucy edmund return...
# 14494  beautiful book illustrate author include tolki...
# 14495  recommend book anyone read child fun keep atte...
# 14496  even today almost six decade since first publi...
# 14497  love book son recommend could imagine enjoy bo...
# 14498                                               like
# 14499  read many clancy jack ryan book natural contin...
#
# [14500 rows x 14 columns]
