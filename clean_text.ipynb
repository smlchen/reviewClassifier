# %%
import numpy as np
import pandas as pd
import nltk
import nltk.corpus
import gzip
import json
import re
from nltk.corpus import wordnet

# %%
def parse(path):
  g = gzip.open(path, 'r')
  for l in g:
    yield json.loads(l)
    
    
def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF("../../Downloads/AMAZON_FASHION_5.json.gz")

# %%
df.head()
# Out:
#    overall  verified  reviewTime     reviewerID        asin  \
# 0      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 1      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 2      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 3      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
# 4      5.0      True  09 4, 2015  ALJ66O1Y6SLHA  B000K2PJ4K
#
#                                                style reviewerName  \
# 0   {'Size:': ' Big Boys', 'Color:': ' Blue/Orange'}     Tonya B.
# 1  {'Size:': ' Big Boys', 'Color:': ' Black (3746...     Tonya B.
# 2  {'Size:': ' Big Boys', 'Color:': ' Blue/Gray L...     Tonya B.
# 3  {'Size:': ' Big Boys', 'Color:': ' Blue (37867...     Tonya B.
# 4     {'Size:': ' Big Boys', 'Color:': ' Blue/Pink'}     Tonya B.
#
#                  reviewText     summary  unixReviewTime vote image
# 0  Great product and price!  Five Stars      1441324800  NaN   NaN
# 1  Great product and price!  Five Stars      1441324800  NaN   NaN
# 2  Great product and price!  Five Stars      1441324800  NaN   NaN
# 3  Great product and price!  Five Stars      1441324800  NaN   NaN
# 4  Great product and price!  Five Stars      1441324800  NaN   NaN

# %%
np.shape(df)
# Out:
# (3176, 12)

# %%
# Drop duplicate reviews
df_nodup = df.drop_duplicates(subset = ['reviewText'])

# %%
def tokenize_text(doc):
    """
    Input: A string of words.
    Output: List of tokenized words that are all lowercase.
    """

    # Tokenize and make lowercase.
    words = nltk.word_tokenize(doc)
    words = [w.lower() for w in words]
    
    return words


def wordnet_pos(tag):
    """
    Map a Brown POS tag to a WordNet POS tag. This is for lemmatization.
    """
    
    table = {"N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV, "J": wordnet.ADJ}
    
    # Default to a noun.
    return table.get(tag[0], wordnet.NOUN)


def lemmatize_text(words):
    """
    Input: A list of tokenized words.
    Output: A list of tokenized words that are lemmatized.
    """
    
    lemmatizer = nltk.WordNetLemmatizer()
    word_tags = nltk.pos_tag(words)
    words = [lemmatizer.lemmatize(w, wordnet_pos(t)) for (w, t) in word_tags]
    
    return words


def remove_stopwords(words):
    """
    Input: A list of tokenized words.
    Output: A list of tokenized words that have stopwords removed.
    """
    
    stopwords = nltk.corpus.stopwords.words("english")
    words = [w for w in words if w not in stopwords]
    
    return words

def clean_text(doc): 
    """
    Input: A string of words.
    Output: A string of words that has been lemmatized, has the stopwords removed, and has the puncuation removed.
    """
    
    words = re.sub("< ?/?[a-z]+ ?>|\n", "", doc)
    words = tokenize_text(words)
    words = lemmatize_text(words)
    words = remove_stopwords(words)
    doc = [w for w in words if w.isalnum()]
    doc = ' '.join(doc)
    
    return doc

def clean_df(df):
    """
    Input: A dataframe with a column of reviews called 'reviewText'.
    Output: The same dataframe as the input, but with an extra column called 'text' which has the 
            cleaned 'reviewText'.
    """
    
    text = df['reviewText']
    df_clean = df.copy()
    df_clean['text'] = [clean_text(str(i)) for i in text]

    return df_clean

# %%
print(df['reviewText'][10])
print(clean_text(df['reviewText'][10]))
# Out:
# Relieved my Plantar Fascitis for 3 Days. Then the unbearable pain returned in full force. These were recommended by my Podiatrist.
# relieve plantar fascitis 3 day unbearable pain return full force recommend podiatrist

# %%
print(df['reviewText'][300])
print(clean_text(df['reviewText'][300]))
# Out:
# Love these sneakers. Light weight and comfortable even without socks.
# love sneaker light weight comfortable even without sock

# %%
# Test the function
clean_df(df_nodup)[['reviewText', 'text']]
# Out:
#                                              reviewText  \
# 0                              Great product and price!
# 5         Waaay too small. Will use for futur children!
# 6                       Stays vibrant after many washes
# 8     My son really likes the pink. Ones which I was...
# 9           Waaay too small. Will use for future child.
# 10    Relieved my Plantar Fascitis for 3 Days. Then ...
# 11    This is my 6th pair and they are the best thin...
# 12    We have used these inserts for years.  They pr...
# 13    Pinnacle seems to have more cushioning so my h...
# 14                  Excellent insole with good support.
# 15    A little more cushion than the Powerstep Prote...
# 16    These insoles help my heels feel much better. ...
# 24                                       Waaaay too BIG
# 25                                          Comfortable
# 26    great price for the product, though the sizes ...
# 27    Good product for the price.  Used very day and...
# 28    Good fit even after washing in hot water to fo...
# 30                       Excellent value.  Comfortable.
# 31    Typical Hanes quality. Good weight, sized just...
# 32    The waist string broke first time trying them ...
# 33    Fit perfectly. I bought dark grey, and they di...
# 34                    They fit great. But they fade bad
# 35    I only give four stars because the pants have ...
# 36                      Average product.  As described.
# 38                                            comfy fit
# 39    Nice pants but too small for a medium. Return it.
# 40    Nice pants but too small for a medium. Returne...
# 41    Very comfy. If they had pockets, theyd be awes...
# 42    Was terribly disappointed, the pants were way ...
# 43                                        As described.
# ...                                                 ...
# 1977    Love these shoes! Great fit, very light weight.
# 2337  Beautiful mirror finish-very comfortable. Look...
# 2338  Love the mirror finish - very comfortable - sc...
# 2339                      very nice...quick shipment...
# 2340                         very nice...quick shipment
# 2341                     very nice ....high quality....
# 2342                                        looks great
# 2343                                                yes
# 2345                                          Very nice
# 2346                                     Would recomend
# 2347  My favorite workout pants.  Have had them seve...
# 2348  I ended up having to throw them out. The insid...
# 2349  WOW!  I love these capris!  I ordered the deep...
# 2350  SO CUTE!!  Very good value. Cute style, pretty...
# 2351  I like it. I wasn't sure if I could pull off t...
# 2352      I used this for a costume and it worked well.
# 2353  Husband was very happy. He now feels like he w...
# 2362  My ring shipped the same day that I placed the...
# 2363  I am changing my review after a second washing...
# 2374          I love this shoes they are so comfortable
# 2375  I absolutely LOVE these shoes. These are my ab...
# 2376                                       Perfect fit!
# 2377                        My favorite cross trainers!
# 2378                              Love them fit perfect
# 2379  Favorite Nike shoe ever! The flex sole is exce...
# 2380       I wear these everyday to work, the gym, etc.
# 3115                Very comfortable and fits perfectly
# 3116                                             Super.
# 3117  Largely my fault for not reading carefully, bu...
# 3130  Size, colour and print all above average but d...
#
#                                                    text
# 0                                   great product price
# 5                           waaay small use futur child
# 6                                stay vibrant many wash
# 8                      son really like pink one nervous
# 9                          waaay small use future child
# 10    relieve plantar fascitis 3 day unbearable pain...
# 11    6th pair best thing ever plantar fasciitis res...
# 12                use insert year provide great support
# 13    pinnacle seem cushioning husband like well try...
# 14                        excellent insole good support
# 15    little cushion powerstep protech arch maybe li...
# 16    insole help heel feel much good would never we...
# 24                                           waaaay big
# 25                                          comfortable
# 26    great price product though size tend big base ...
# 27                  good product price used day problem
# 28    good fit even wash hot water force shrink 30 i...
# 30                          excellent value comfortable
# 31    typical hanes quality good weight size right m...
# 32    waist string break first time try luckily real...
# 33                     fit perfectly buy dark grey fade
# 34                                   fit great fade bad
# 35                           give four star pant pocket
# 36                            average product described
# 38                                            comfy fit
# 39                        nice pant small medium return
# 40                        nice pant small medium return
# 41    comfy pocket theyd awesome buy lounge around h...
# 42    terribly disappointed pant way large leg husba...
# 43                                             describe
# ...                                                 ...
# 1977                   love shoe great fit light weight
# 2337  beautiful mirror comfortable look great white ...
# 2338  love mirror finish comfortable scratchproof pa...
# 2339                                nice quick shipment
# 2340                                nice quick shipment
# 2341                                       nice quality
# 2342                                         look great
# 2343                                                yes
# 2345                                               nice
# 2346                                     would recomend
# 2347  favorite workout pant several month use severa...
# 2348  end throw inside seam around private area unra...
# 2349  wow love capri order deep teal dark much deep ...
# 2350  cute good value cute style pretty color soft m...
# 2351  like sure could pull kind hat look good fit ni...
# 2352                              use costume work well
# 2353  husband happy feel like would fit set downton ...
# 2362  ring ship day place order receive well estimat...
# 2363  change review second male size 9 wide wash tig...
# 2374                              love shoe comfortable
# 2375  absolutely love shoe absolute favorite light c...
# 2376                                        perfect fit
# 2377                             favorite cross trainer
# 2378                                   love fit perfect
# 2379  favorite nike shoe ever flex sole excellent so...
# 2380                         wear everyday work gym etc
# 3115                          comfortable fit perfectly
# 3116                                              super
# 3117  largely fault read carefully high synthetic fi...
# 3130               size colour print average wash great
#
# [439 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range=(1,3), norm='l2')

tmp = df['text']

vectorizer.fit(tmp)

tmp_tfidf = vectorizer.transform(tmp)

# %%
tmp_tfidf
# Out:
# <3176x9341 sparse matrix of type '<class 'numpy.float64'>'
# 	with 101439 stored elements in Compressed Sparse Row format>
